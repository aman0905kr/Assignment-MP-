# %% [markdown]
# Generating data for ~50mb csv file [1_000_000 rows]

# %%
import pandas as pd
import os
import random
from datetime import datetime
import numpy as np
from datetime import datetime

random.seed(42)

def generate_mock_csv(file_path, num_rows=1000000):
    log_id = np.random.randint(1, high=100_0000, size=(num_rows), dtype=int)
    user_id = np.random.randint(1, high=100_000, size=(num_rows), dtype=int)
    watch_time = np.random.randint(1, 180, size=(num_rows), dtype=int)

    random_seconds = np.random.randint(0, 24 * 60 * 60, size=num_rows)
    
    # Fast vectorized conversion using numpy datetime64
    base_timestamp = np.datetime64(datetime.now())
    timestamp = base_timestamp + random_seconds.astype('timedelta64[s]')
    timestamp = timestamp.reshape(-1)
    
    # ip_address = np.array([fake.ipv4() for _ in range(num_rows)]).reshape(-1,1)

    ip_address = np.random.randint(1,high=256, size=(num_rows),dtype=int)

    df = pd.DataFrame({
        "log_id": log_id,
        "user_id": user_id, 
        "watch_time(min)": watch_time,
        "timestamp": timestamp,
        "ip_address": ip_address
    })    

    df.to_csv(file_path, index=False)

def generate_multiple_files(output_dir, num_files=1):
    os.makedirs(output_dir, exist_ok=True)
    for i in range(1, num_files + 1):
        file_path = os.path.join(output_dir, f"user_activity_{i}.csv")
        # generate_mock_csv(file_path, num_rows=random.randint(3000, 8000))
        generate_mock_csv(file_path, num_rows=1000000)
        print(f"✅ Generated {file_path}")

if __name__ == "__main__":
    generate_multiple_files("data/mock_csvs", num_files=100)
# Out:
# ✅ Generated data/mock_csvs/user_activity_1.csv
# ✅ Generated data/mock_csvs/user_activity_2.csv
# ✅ Generated data/mock_csvs/user_activity_3.csv
# ✅ Generated data/mock_csvs/user_activity_4.csv
# ✅ Generated data/mock_csvs/user_activity_5.csv
# ✅ Generated data/mock_csvs/user_activity_6.csv
# ✅ Generated data/mock_csvs/user_activity_7.csv
# ✅ Generated data/mock_csvs/user_activity_8.csv
# ✅ Generated data/mock_csvs/user_activity_9.csv
# ✅ Generated data/mock_csvs/user_activity_10.csv
# ✅ Generated data/mock_csvs/user_activity_11.csv
# ✅ Generated data/mock_csvs/user_activity_12.csv
# ✅ Generated data/mock_csvs/user_activity_13.csv
# ✅ Generated data/mock_csvs/user_activity_14.csv
# ✅ Generated data/mock_csvs/user_activity_15.csv
# ✅ Generated data/mock_csvs/user_activity_16.csv
# ✅ Generated data/mock_csvs/user_activity_17.csv
# ✅ Generated data/mock_csvs/user_activity_18.csv
# ✅ Generated data/mock_csvs/user_activity_19.csv
# ✅ Generated data/mock_csvs/user_activity_20.csv
# ✅ Generated data/mock_csvs/user_activity_21.csv
# ✅ Generated data/mock_csvs/user_activity_22.csv
# ✅ Generated data/mock_csvs/user_activity_23.csv
# ✅ Generated data/mock_csvs/user_activity_24.csv
# ✅ Generated data/mock_csvs/user_activity_25.csv
# ✅ Generated data/mock_csvs/user_activity_26.csv
# ✅ Generated data/mock_csvs/user_activity_27.csv
# ✅ Generated data/mock_csvs/user_activity_28.csv
# ✅ Generated data/mock_csvs/user_activity_29.csv
# ✅ Generated data/mock_csvs/user_activity_30.csv
# ✅ Generated data/mock_csvs/user_activity_31.csv
# ✅ Generated data/mock_csvs/user_activity_32.csv
# ✅ Generated data/mock_csvs/user_activity_33.csv
# ✅ Generated data/mock_csvs/user_activity_34.csv
# ✅ Generated data/mock_csvs/user_activity_35.csv
# ✅ Generated data/mock_csvs/user_activity_36.csv
# ✅ Generated data/mock_csvs/user_activity_37.csv
# ✅ Generated data/mock_csvs/user_activity_38.csv
# ✅ Generated data/mock_csvs/user_activity_39.csv
# ✅ Generated data/mock_csvs/user_activity_40.csv
# ✅ Generated data/mock_csvs/user_activity_41.csv
# ✅ Generated data/mock_csvs/user_activity_42.csv
# ✅ Generated data/mock_csvs/user_activity_43.csv
# ✅ Generated data/mock_csvs/user_activity_44.csv
# ✅ Generated data/mock_csvs/user_activity_45.csv
# ✅ Generated data/mock_csvs/user_activity_46.csv
# ✅ Generated data/mock_csvs/user_activity_47.csv
# ✅ Generated data/mock_csvs/user_activity_48.csv
# ✅ Generated data/mock_csvs/user_activity_49.csv
# ✅ Generated data/mock_csvs/user_activity_50.csv
# ✅ Generated data/mock_csvs/user_activity_51.csv
# ✅ Generated data/mock_csvs/user_activity_52.csv
# ✅ Generated data/mock_csvs/user_activity_53.csv
# ✅ Generated data/mock_csvs/user_activity_54.csv
# ✅ Generated data/mock_csvs/user_activity_55.csv
# ✅ Generated data/mock_csvs/user_activity_56.csv
# ✅ Generated data/mock_csvs/user_activity_57.csv
# ✅ Generated data/mock_csvs/user_activity_58.csv
# ✅ Generated data/mock_csvs/user_activity_59.csv
# ✅ Generated data/mock_csvs/user_activity_60.csv
# ✅ Generated data/mock_csvs/user_activity_61.csv
# ✅ Generated data/mock_csvs/user_activity_62.csv
# ✅ Generated data/mock_csvs/user_activity_63.csv
# ✅ Generated data/mock_csvs/user_activity_64.csv
# ✅ Generated data/mock_csvs/user_activity_65.csv
# ✅ Generated data/mock_csvs/user_activity_66.csv
# ✅ Generated data/mock_csvs/user_activity_67.csv
# ✅ Generated data/mock_csvs/user_activity_68.csv
# ✅ Generated data/mock_csvs/user_activity_69.csv
# ✅ Generated data/mock_csvs/user_activity_70.csv
# ✅ Generated data/mock_csvs/user_activity_71.csv
# ✅ Generated data/mock_csvs/user_activity_72.csv
# ✅ Generated data/mock_csvs/user_activity_73.csv
# ✅ Generated data/mock_csvs/user_activity_74.csv
# ✅ Generated data/mock_csvs/user_activity_75.csv
# ✅ Generated data/mock_csvs/user_activity_76.csv
# ✅ Generated data/mock_csvs/user_activity_77.csv
# ✅ Generated data/mock_csvs/user_activity_78.csv
# ✅ Generated data/mock_csvs/user_activity_79.csv
# ✅ Generated data/mock_csvs/user_activity_80.csv
# ✅ Generated data/mock_csvs/user_activity_81.csv
# ✅ Generated data/mock_csvs/user_activity_82.csv
# ✅ Generated data/mock_csvs/user_activity_83.csv
# ✅ Generated data/mock_csvs/user_activity_84.csv
# ✅ Generated data/mock_csvs/user_activity_85.csv
# ✅ Generated data/mock_csvs/user_activity_86.csv
# ✅ Generated data/mock_csvs/user_activity_87.csv
# ✅ Generated data/mock_csvs/user_activity_88.csv
# ✅ Generated data/mock_csvs/user_activity_89.csv
# ✅ Generated data/mock_csvs/user_activity_90.csv
# ✅ Generated data/mock_csvs/user_activity_91.csv
# ✅ Generated data/mock_csvs/user_activity_92.csv
# ✅ Generated data/mock_csvs/user_activity_93.csv
# ✅ Generated data/mock_csvs/user_activity_94.csv
# ✅ Generated data/mock_csvs/user_activity_95.csv
# ✅ Generated data/mock_csvs/user_activity_96.csv
# ✅ Generated data/mock_csvs/user_activity_97.csv
# ✅ Generated data/mock_csvs/user_activity_98.csv
# ✅ Generated data/mock_csvs/user_activity_99.csv
# ✅ Generated data/mock_csvs/user_activity_100.csv

# %% [markdown]
# Generating data for ~50mb csv file [10_000_000 rows]

# %%
import os
import numpy as np
import pandas as pd
from datetime import datetime


def generate_mock_csv(file_path, num_rows, id_offset=0):

    log_id = np.random.randint(1, high=10000001, size=num_rows) + id_offset  
    user_id = np.random.randint(1, high=1000001, size=num_rows)
    watch_time = np.random.randint(1, 181, size=num_rows)
    base_ts = np.datetime64(datetime.now())
    random_seconds = np.random.randint(0, 24*60*60, size=num_rows)
    timestamp = (base_ts + random_seconds.astype('timedelta64[s]')).reshape(-1)
    ip_address = np.random.randint(1, 256, size=num_rows)
    
    df = pd.DataFrame({
        "log_id": log_id,
        "user_id": user_id,
        "watch_time(min)": watch_time,
        "timestamp": timestamp,
        "ip_address": ip_address,
    })
    df.to_csv(file_path, index=False)

def generate_multiple_files(output_dir, num_files=100):
    os.makedirs(output_dir, exist_ok=True)
    RANGE_PER_FILE = 1_000_000
    for i in range(1, num_files+1):
        offset = (i - 1) * RANGE_PER_FILE
        file_path = os.path.join(output_dir, f"user_activity_{i}.csv")
        generate_mock_csv(file_path, num_rows=10_000_000, id_offset=offset)
        print(f"✅ Generated {file_path}  (IDs {offset+1}–{offset+RANGE_PER_FILE})")

# %%
if __name__ == "__main__":
    generate_multiple_files("data/mock_csvs_final", num_files=100)
# Out:
# ✅ Generated data/mock_csvs_final/user_activity_1.csv  (IDs 1–1000000)
# ✅ Generated data/mock_csvs_final/user_activity_2.csv  (IDs 1000001–2000000)
# ✅ Generated data/mock_csvs_final/user_activity_3.csv  (IDs 2000001–3000000)
# ✅ Generated data/mock_csvs_final/user_activity_4.csv  (IDs 3000001–4000000)
# ✅ Generated data/mock_csvs_final/user_activity_5.csv  (IDs 4000001–5000000)
# ✅ Generated data/mock_csvs_final/user_activity_6.csv  (IDs 5000001–6000000)
# ✅ Generated data/mock_csvs_final/user_activity_7.csv  (IDs 6000001–7000000)
# ✅ Generated data/mock_csvs_final/user_activity_8.csv  (IDs 7000001–8000000)
# ✅ Generated data/mock_csvs_final/user_activity_9.csv  (IDs 8000001–9000000)
# ✅ Generated data/mock_csvs_final/user_activity_10.csv  (IDs 9000001–10000000)
# ✅ Generated data/mock_csvs_final/user_activity_11.csv  (IDs 10000001–11000000)
# ✅ Generated data/mock_csvs_final/user_activity_12.csv  (IDs 11000001–12000000)
# ✅ Generated data/mock_csvs_final/user_activity_13.csv  (IDs 12000001–13000000)
# ✅ Generated data/mock_csvs_final/user_activity_14.csv  (IDs 13000001–14000000)
# ✅ Generated data/mock_csvs_final/user_activity_15.csv  (IDs 14000001–15000000)
# ✅ Generated data/mock_csvs_final/user_activity_16.csv  (IDs 15000001–16000000)
# ✅ Generated data/mock_csvs_final/user_activity_17.csv  (IDs 16000001–17000000)
# ✅ Generated data/mock_csvs_final/user_activity_18.csv  (IDs 17000001–18000000)
# ✅ Generated data/mock_csvs_final/user_activity_19.csv  (IDs 18000001–19000000)
# ✅ Generated data/mock_csvs_final/user_activity_20.csv  (IDs 19000001–20000000)
# ✅ Generated data/mock_csvs_final/user_activity_21.csv  (IDs 20000001–21000000)
# ✅ Generated data/mock_csvs_final/user_activity_22.csv  (IDs 21000001–22000000)
# ✅ Generated data/mock_csvs_final/user_activity_23.csv  (IDs 22000001–23000000)
# ✅ Generated data/mock_csvs_final/user_activity_24.csv  (IDs 23000001–24000000)
# ✅ Generated data/mock_csvs_final/user_activity_25.csv  (IDs 24000001–25000000)
# ✅ Generated data/mock_csvs_final/user_activity_26.csv  (IDs 25000001–26000000)
# ✅ Generated data/mock_csvs_final/user_activity_27.csv  (IDs 26000001–27000000)
# ✅ Generated data/mock_csvs_final/user_activity_28.csv  (IDs 27000001–28000000)
# ✅ Generated data/mock_csvs_final/user_activity_29.csv  (IDs 28000001–29000000)
# ✅ Generated data/mock_csvs_final/user_activity_30.csv  (IDs 29000001–30000000)
# ✅ Generated data/mock_csvs_final/user_activity_31.csv  (IDs 30000001–31000000)
# ✅ Generated data/mock_csvs_final/user_activity_32.csv  (IDs 31000001–32000000)
# ✅ Generated data/mock_csvs_final/user_activity_33.csv  (IDs 32000001–33000000)
# ✅ Generated data/mock_csvs_final/user_activity_34.csv  (IDs 33000001–34000000)
# ✅ Generated data/mock_csvs_final/user_activity_35.csv  (IDs 34000001–35000000)
# ✅ Generated data/mock_csvs_final/user_activity_36.csv  (IDs 35000001–36000000)
# ✅ Generated data/mock_csvs_final/user_activity_37.csv  (IDs 36000001–37000000)
# ✅ Generated data/mock_csvs_final/user_activity_38.csv  (IDs 37000001–38000000)
# ✅ Generated data/mock_csvs_final/user_activity_39.csv  (IDs 38000001–39000000)
# ✅ Generated data/mock_csvs_final/user_activity_40.csv  (IDs 39000001–40000000)
# ✅ Generated data/mock_csvs_final/user_activity_41.csv  (IDs 40000001–41000000)
# ✅ Generated data/mock_csvs_final/user_activity_42.csv  (IDs 41000001–42000000)
# ✅ Generated data/mock_csvs_final/user_activity_43.csv  (IDs 42000001–43000000)
# ✅ Generated data/mock_csvs_final/user_activity_44.csv  (IDs 43000001–44000000)
# ✅ Generated data/mock_csvs_final/user_activity_45.csv  (IDs 44000001–45000000)
# ✅ Generated data/mock_csvs_final/user_activity_46.csv  (IDs 45000001–46000000)
# ✅ Generated data/mock_csvs_final/user_activity_47.csv  (IDs 46000001–47000000)
# ✅ Generated data/mock_csvs_final/user_activity_48.csv  (IDs 47000001–48000000)
# ✅ Generated data/mock_csvs_final/user_activity_49.csv  (IDs 48000001–49000000)
# ✅ Generated data/mock_csvs_final/user_activity_50.csv  (IDs 49000001–50000000)
# ✅ Generated data/mock_csvs_final/user_activity_51.csv  (IDs 50000001–51000000)
# ✅ Generated data/mock_csvs_final/user_activity_52.csv  (IDs 51000001–52000000)
# ✅ Generated data/mock_csvs_final/user_activity_53.csv  (IDs 52000001–53000000)
# ✅ Generated data/mock_csvs_final/user_activity_54.csv  (IDs 53000001–54000000)
# ✅ Generated data/mock_csvs_final/user_activity_55.csv  (IDs 54000001–55000000)
# ✅ Generated data/mock_csvs_final/user_activity_56.csv  (IDs 55000001–56000000)
# ✅ Generated data/mock_csvs_final/user_activity_57.csv  (IDs 56000001–57000000)
# ✅ Generated data/mock_csvs_final/user_activity_58.csv  (IDs 57000001–58000000)
# ✅ Generated data/mock_csvs_final/user_activity_59.csv  (IDs 58000001–59000000)
# ✅ Generated data/mock_csvs_final/user_activity_60.csv  (IDs 59000001–60000000)
# ✅ Generated data/mock_csvs_final/user_activity_61.csv  (IDs 60000001–61000000)
# ✅ Generated data/mock_csvs_final/user_activity_62.csv  (IDs 61000001–62000000)
# ✅ Generated data/mock_csvs_final/user_activity_63.csv  (IDs 62000001–63000000)
# ✅ Generated data/mock_csvs_final/user_activity_64.csv  (IDs 63000001–64000000)
# ✅ Generated data/mock_csvs_final/user_activity_65.csv  (IDs 64000001–65000000)
# ✅ Generated data/mock_csvs_final/user_activity_66.csv  (IDs 65000001–66000000)
# ✅ Generated data/mock_csvs_final/user_activity_67.csv  (IDs 66000001–67000000)
# ✅ Generated data/mock_csvs_final/user_activity_68.csv  (IDs 67000001–68000000)
# ✅ Generated data/mock_csvs_final/user_activity_69.csv  (IDs 68000001–69000000)
# ✅ Generated data/mock_csvs_final/user_activity_70.csv  (IDs 69000001–70000000)
# ✅ Generated data/mock_csvs_final/user_activity_71.csv  (IDs 70000001–71000000)
# ✅ Generated data/mock_csvs_final/user_activity_72.csv  (IDs 71000001–72000000)
# ✅ Generated data/mock_csvs_final/user_activity_73.csv  (IDs 72000001–73000000)
# ✅ Generated data/mock_csvs_final/user_activity_74.csv  (IDs 73000001–74000000)
# ✅ Generated data/mock_csvs_final/user_activity_75.csv  (IDs 74000001–75000000)
# ✅ Generated data/mock_csvs_final/user_activity_76.csv  (IDs 75000001–76000000)
# ✅ Generated data/mock_csvs_final/user_activity_77.csv  (IDs 76000001–77000000)
# ✅ Generated data/mock_csvs_final/user_activity_78.csv  (IDs 77000001–78000000)
# ✅ Generated data/mock_csvs_final/user_activity_79.csv  (IDs 78000001–79000000)
# ✅ Generated data/mock_csvs_final/user_activity_80.csv  (IDs 79000001–80000000)
# ✅ Generated data/mock_csvs_final/user_activity_81.csv  (IDs 80000001–81000000)
# ✅ Generated data/mock_csvs_final/user_activity_82.csv  (IDs 81000001–82000000)
# ✅ Generated data/mock_csvs_final/user_activity_83.csv  (IDs 82000001–83000000)
# ✅ Generated data/mock_csvs_final/user_activity_84.csv  (IDs 83000001–84000000)
# ✅ Generated data/mock_csvs_final/user_activity_85.csv  (IDs 84000001–85000000)
# ✅ Generated data/mock_csvs_final/user_activity_86.csv  (IDs 85000001–86000000)
# ✅ Generated data/mock_csvs_final/user_activity_87.csv  (IDs 86000001–87000000)
# ✅ Generated data/mock_csvs_final/user_activity_88.csv  (IDs 87000001–88000000)
# ✅ Generated data/mock_csvs_final/user_activity_89.csv  (IDs 88000001–89000000)
# ✅ Generated data/mock_csvs_final/user_activity_90.csv  (IDs 89000001–90000000)
# ✅ Generated data/mock_csvs_final/user_activity_91.csv  (IDs 90000001–91000000)
# ✅ Generated data/mock_csvs_final/user_activity_92.csv  (IDs 91000001–92000000)
# ✅ Generated data/mock_csvs_final/user_activity_93.csv  (IDs 92000001–93000000)
# ✅ Generated data/mock_csvs_final/user_activity_94.csv  (IDs 93000001–94000000)
# ✅ Generated data/mock_csvs_final/user_activity_95.csv  (IDs 94000001–95000000)
# ✅ Generated data/mock_csvs_final/user_activity_96.csv  (IDs 95000001–96000000)
# ✅ Generated data/mock_csvs_final/user_activity_97.csv  (IDs 96000001–97000000)
# ✅ Generated data/mock_csvs_final/user_activity_98.csv  (IDs 97000001–98000000)
# ✅ Generated data/mock_csvs_final/user_activity_99.csv  (IDs 98000001–99000000)
# ✅ Generated data/mock_csvs_final/user_activity_100.csv  (IDs 99000001–100000000)
